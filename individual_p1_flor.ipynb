# %%
"""Julia set generator without optional PIL-based image drawing"""
import time
from PIL import Image
import array

# area of complex space to investigate
x1, x2, y1, y2 = -1.8, 1.8, -1.8, 1.8
c_real, c_imag = -0.62772, -.42193


def show_greyscale(output_raw, width, height, max_iterations):
    """Convert list to array, show using PIL"""
    # convert our output to PIL-compatible input
    # scale to [0...255]
    max_iterations = float(max(output_raw))
    print(max_iterations)
    scale_factor = float(max_iterations)
    scaled = [int(o / scale_factor * 255) for o in output_raw]
    output = array.array('B', scaled)  # array of unsigned ints
    # display with PIL
    im = Image.new("L", (width, width))
    # EXPLAIN RAW L 0 -1
    im.frombytes(output.tobytes(), "raw", "L", 0, -1)
    im.show()


def show_false_greyscale(output_raw, width, height, max_iterations):
    """Convert list to array, show using PIL"""
    # convert our output to PIL-compatible input
    assert width * height == len(output_raw)  # sanity check our 1D array and desired 2D form
    # rescale output_raw to be in the inclusive range [0..255]
    max_value = float(max(output_raw))
    output_raw_limited = [int(float(o) / max_value * 255) for o in output_raw]
    # create a slightly fancy colour map that shows colour changes with
    # increased contrast (thanks to John Montgomery)
    output_rgb = ((o + (256 * o) + (256 ** 2) * o) * 16 for o in output_raw_limited)  # fancier
    output_rgb = array.array('I', output_rgb)  # array of unsigned ints (size is platform specific)
    # display with PIL/pillow
    im = Image.new("RGB", (width, height))
    # EXPLAIN RGBX L 0 -1
    im.frombytes(output_rgb.tobytes(), "raw", "RGBX", 0, -1)
    im.show()


def calculate_z_serial_purepython(maxiter, zs, cs):
    """Calculate output list using Julia update rule"""
    output = [0] * len(zs)
    for i in range(len(zs)):
        n = 0
        z = zs[i]
        c = cs[i]
        while abs(z) < 2 and n < maxiter:
            z = z * z + c
            n += 1
        output[i] = n
    return output


def calc_pure_python(draw_output, desired_width, max_iterations):
    """Create a list of complex co-ordinates (zs) and complex parameters (cs), build Julia set and display"""
    x_step = (x2 - x1) / desired_width
    y_step = (y1 - y2) / desired_width
    x = []
    y = []
    ycoord = y2
    while ycoord > y1:
        y.append(ycoord)
        ycoord += y_step
    xcoord = x1
    while xcoord < x2:
        x.append(xcoord)
        xcoord += x_step
    # set width and height to the generated pixel counts, rather than the
    # pre-rounding desired width and height
    width = len(x)
    height = len(y)
    # build a list of co-ordinates and the initial condition for each cell.
    # Note that our initial condition is a constant and could easily be removed,
    # we use it to simulate a real-world scenario with several inputs to our function
    zs = []
    cs = []
    for ycoord in y:
        for xcoord in x:
            zs.append(complex(xcoord, ycoord))
            cs.append(complex(c_real, c_imag))

    print("Length of x:", len(x))
    print("Total elements:", len(zs))
    start_time = time.time()
    output = calculate_z_serial_purepython(max_iterations, zs, cs)
    end_time = time.time()
    secs = end_time - start_time
    print(calculate_z_serial_purepython.__name__ + " took", secs, "seconds")

    assert sum(output) == 33219980  # this sum is expected for 1000^2 grid with 300 iterations

    if draw_output:
        show_false_greyscale(output, width, height, max_iterations)
        show_greyscale(output, width, height, max_iterations)


if __name__ == "__main__":
    # Calculate the Julia set using a pure Python solution with
    # reasonable defaults for a laptop
    # set draw_output to True to use PIL to draw an image
    calc_pure_python(draw_output=True, desired_width=1000, max_iterations=300)
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 12.081302642822266 seconds
# 300.0

# %%
# %timeit -r 5 -n 10 calc_pure_python(draw_output=False, desired_width=1000, max_iterations=300)
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 19.2152099609375 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 16.54414963722229 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 22.47481417655945 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 31.82246732711792 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 26.29069757461548 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 27.48933506011963 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 29.879351377487183 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 19.673796892166138 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 24.811880350112915 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 20.489314317703247 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 19.464406967163086 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 19.980096578598022 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 19.285154342651367 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 20.937108039855957 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 22.960540533065796 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 17.4324209690094 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 17.517767429351807 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 20.63111138343811 seconds
# Length of x: 1000
# Total elements: 1000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().run_line_magic('timeit', '-r 5 -n 10 calc_pure_python(draw_output=False, desired_width=1000, max_iterations=300)')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\magics\execution.py:1189, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1186         if time_number >= 0.2:
#    1187             break
# -> 1189 all_runs = timer.repeat(repeat, number)
#    1190 best = min(all_runs) / number
#    1191 worst = max(all_runs) / number
#
# File c:\Users\Thana\AppData\Local\Programs\Python\Python312\Lib\timeit.py:208, in Timer.repeat(self, repeat, number)
#     206 r = []
#     207 for i in range(repeat):
# --> 208     t = self.timeit(number)
#     209     r.append(t)
#     210 return r
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\magics\execution.py:173, in Timer.timeit(self, number)
#     171 gc.disable()
#     172 try:
# --> 173     timing = self.inner(it, self.timer)
#     174 finally:
#     175     if gcold:
#
# File <magic-timeit>:1, in inner(_it, _timer)
#
# Cell In[2], line 90, in calc_pure_python(draw_output, desired_width, max_iterations)
#      88 print("Total elements:", len(zs))
#      89 start_time = time.time()
# ---> 90 output = calculate_z_serial_purepython(max_iterations, zs, cs)
#      91 end_time = time.time()
#      92 secs = end_time - start_time
#
# Cell In[2], line 52, in calculate_z_serial_purepython(maxiter, zs, cs)
#      50 z = zs[i]
#      51 c = cs[i]
# ---> 52 while abs(z) < 2 and n < maxiter:
#      53     z = z * z + c
#      54     n += 1
#
# KeyboardInterrupt:

# %%
import cProfile
import pstats

# Create a Profile object
profiler = cProfile.Profile()

# Start profiling
profiler.enable()

# Run your function
calc_pure_python(draw_output=False, desired_width=1000, max_iterations=300)

# Stop profiling
profiler.disable()

# Create a Stats object
stats = pstats.Stats(profiler)

# Clean up filenames for the report
stats.strip_dirs()

# Sort the statistics by the cumulative time spent
stats.sort_stats('time')

# Print out all the statistics
stats.print_stats()
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 55.93590974807739 seconds
#          36223471 function calls (36223383 primitive calls) in 59.742 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      15/0   27.851    1.857    0.000          {built-in method select.select}
#  34219980   22.294    0.000   22.294    0.000 {built-in method builtins.abs}
#         1    5.787    5.787    9.559    9.559 890625955.py:45(calculate_z_serial_purepython)
#      15/0    2.527    0.168    0.000          selectors.py:313(_select)
#   2002006    1.096    0.000    1.096    0.000 {method 'append' of 'list' objects}
#        22    0.096    0.004    0.135    0.006 socket.py:621(send)
#         1    0.065    0.065    0.065    0.065 4057984789.py:1(<module>)
#         1    0.010    0.010    0.010    0.010 {built-in method builtins.sum}
#        18    0.001    0.000    0.001    0.000 threading.py:1220(is_alive)
#      15/0    0.001    0.000    0.000          base_events.py:1908(_run_once)
#         5    0.001    0.000    0.001    0.000 events.py:155(cancel)
#         3    0.001    0.000    0.004    0.001 {built-in method builtins.print}
#         9    0.001    0.000    0.001    0.000 attrsettr.py:65(_get_attr_opt)
#         2    0.000    0.000    0.031    0.016 socket.py:698(send_multipart)
#         2    0.000    0.000    0.001    0.000 codeop.py:121(__call__)
#      15/0    0.000    0.000    0.000          selectors.py:319(select)
#        19    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#        19    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#        14    0.000    0.000    0.001    0.000 iostream.py:655(write)
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#        10    0.000    0.000    0.001    0.000 tasks.py:653(sleep)
#        21    0.000    0.000    0.000    0.000 enum.py:1531(__or__)
#         9    0.000    0.000    0.001    0.000 attrsettr.py:42(__getattr__)
#   148/138    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        15    0.000    0.000    0.020    0.001 {method 'run' of '_contextvars.Context' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        14    0.000    0.000    0.000    0.000 enum.py:1541(__and__)
#         4    0.000    0.000    0.000    0.000 socket.py:777(recv_multipart)
#         4    0.000    0.000    0.002    0.001 zmqstream.py:607(_handle_events)
#        15    0.000    0.000    0.020    0.001 events.py:86(_run)
#         5    0.000    0.000    0.000    0.000 iostream.py:127(_event_pipe_gc)
#        48    0.000    0.000    0.000    0.000 enum.py:713(__call__)
#        32    0.000    0.000    0.000    0.000 base_events.py:732(time)
#         4    0.000    0.000    0.000    0.000 encoder.py:205(iterencode)
#         4    0.000    0.000    0.001    0.000 iostream.py:157(_handle_event)
#        48    0.000    0.000    0.000    0.000 enum.py:1116(__new__)
#         5    0.000    0.000    0.002    0.000 iostream.py:118(_run_event_pipe_gc)
#        13    0.000    0.000    0.000    0.000 events.py:36(__init__)
#        71    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        17    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         7    0.000    0.000    0.000    0.000 base_events.py:765(call_at)
#         7    0.000    0.000    0.000    0.000 base_events.py:741(call_later)
#        12    0.000    0.000    0.000    0.000 typing.py:378(inner)
#         4    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        29    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.015    0.015 iostream.py:616(_flush)
#         1    0.000    0.000    0.015    0.015 session.py:754(send)
#         5    0.000    0.000    0.001    0.000 zmqstream.py:687(_rebuild_io_state)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         6    0.000    0.000    0.000    0.000 base_events.py:812(_call_soon)
#        19    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#        13    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#      20/2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#        18    0.000    0.000    0.000    0.000 threading.py:1153(_wait_for_tstate_lock)
#        15    0.000    0.000    0.000    0.000 selector_events.py:750(_process_events)
#         4    0.000    0.000    0.000    0.000 __init__.py:183(dumps)
#         5    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.031    0.016 iostream.py:278(_really_send)
#         1    0.000    0.000    0.000    0.000 queues.py:225(get)
#         5    0.000    0.000    0.000    0.000 base_events.py:446(create_future)
#         5    0.000    0.000    0.000    0.000 futures.py:311(_set_result_unless_cancelled)
#         5    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         5    0.000    0.000    0.000    0.000 typing.py:1446(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 iostream.py:710(_flush_buffers)
#        32    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#        14    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#         4    0.000    0.000    0.001    0.000 zmqstream.py:648(_handle_recv)
#         4    0.000    0.000    0.000    0.000 encoder.py:183(encode)
#         7    0.000    0.000    0.000    0.000 events.py:111(__init__)
#         1    0.000    0.000    0.001    0.001 session.py:690(serialize)
#         3    0.000    0.000    0.014    0.005 iostream.py:259(schedule)
#         5    0.000    0.000    0.001    0.000 zmqstream.py:710(_update_handler)
#         1    0.000    0.000    0.000    0.000 890625955.py:59(calc_pure_python)
#         2    0.000    0.000    0.016    0.008 ioloop.py:742(_run_callback)
#         6    0.000    0.000    0.000    0.000 base_events.py:783(call_soon)
#         5    0.000    0.000    0.000    0.000 typing.py:1175(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#        20    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         3    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         4    0.000    0.000    0.000    0.000 session.py:92(json_packer)
#         2    0.000    0.000    0.031    0.016 iostream.py:276(<lambda>)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         8    0.000    0.000    0.000    0.000 typing.py:1239(__hash__)
#         1    0.000    0.000    0.000    0.000 asyncio.py:225(add_callback)
#         1    0.000    0.000    0.000    0.000 hmac.py:122(copy)
#        14    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#         4    0.000    0.000    0.001    0.000 zmqstream.py:580(_run_callback)
#        20    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         2    0.000    0.000    0.000    0.000 jsonutil.py:107(json_default)
#         3    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#        19    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         2    0.000    0.000    0.000    0.000 asyncio.py:210(call_at)
#        55    0.000    0.000    0.000    0.000 typing.py:2132(cast)
#        14    0.000    0.000    0.000    0.000 iostream.py:577(_schedule_flush)
#         6    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 session.py:649(msg)
#         2    0.000    0.000    0.065    0.033 interactiveshell.py:3541(run_code)
#         1    0.000    0.000    0.000    0.000 session.py:675(sign)
#         5    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         7    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         1    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#        14    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 contextlib.py:104(__init__)
#         5    0.000    0.000    0.000    0.000 events.py:72(cancel)
#         9    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         2    0.000    0.000    0.000    0.000 ioloop.py:596(call_later)
#        14    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         4    0.000    0.000    0.000    0.000 ioloop.py:541(time)
#         5    0.000    0.000    0.000    0.000 zmqstream.py:566(sending)
#         2    0.000    0.000    0.065    0.033 {built-in method builtins.exec}
#         3    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         3    0.000    0.000    0.002    0.001 asyncio.py:200(_handle_events)
#         8    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#        12    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        15    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#        18    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#         2    0.000    0.000    0.000    0.000 iostream.py:587(_schedule_in_thread)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         6    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         2    0.000    0.000    0.000    0.000 contextlib.py:299(helper)
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:718(_rotate_buffers)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 traitlets.py:2635(validate)
#         8    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         2    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         5    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#        24    0.000    0.000    0.000    0.000 base_events.py:2003(get_debug)
#         1    0.000    0.000    0.000    0.000 session.py:600(msg_id)
#         2    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 session.py:645(msg_header)
#         1    0.000    0.000    0.000    0.000 session.py:281(extract_header)
#        13    0.000    0.000    0.000    0.000 base_events.py:538(_check_closed)
#         4    0.000    0.000    0.000    0.000 hmac.py:117(update)
#         5    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         4    0.000    0.000    0.000    0.000 compilerop.py:180(extra_flags)
#         1    0.000    0.000    0.000    0.000 session.py:198(utcnow)
#         1    0.000    0.000    0.000    0.000 session.py:272(msg_header)
#         1    0.000    0.000    0.000    0.000 {built-in method now}
#         2    0.000    0.000    0.000    0.000 contextlib.py:132(__enter__)
#         6    0.000    0.000    0.000    0.000 {built-in method time.time}
#         4    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#         5    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#         3    0.000    0.000    0.000    0.000 base_events.py:1893(_add_callback)
#         1    0.000    0.000    0.000    0.000 hmac.py:161(hexdigest)
#         1    0.000    0.000    0.014    0.014 iostream.py:271(send_multipart)
#         9    0.000    0.000    0.000    0.000 zmqstream.py:562(receiving)
#         1    0.000    0.000    0.001    0.001 zmqstream.py:718(<lambda>)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         2    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#         4    0.000    0.000    0.000    0.000 encoder.py:105(__init__)
#         1    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         3    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         5    0.000    0.000    0.000    0.000 base_events.py:1903(_timer_handle_cancelled)
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         2    0.000    0.000    0.000    0.000 jsonutil.py:38(_ensure_tzinfo)
#         2    0.000    0.000    0.000    0.000 interactiveshell.py:3493(compare)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         4    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:725(_hooks)
#         2    0.000    0.000    0.000    0.000 events.py:127(__lt__)
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         2    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         2    0.000    0.000    0.000    0.000 interactiveshell.py:1277(user_global_ns)
#         1    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFFCC3998B0}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 traitlets.py:2558(_validate_bounds)
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 hmac.py:139(_current)
